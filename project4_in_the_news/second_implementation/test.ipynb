# %%
from urllib.request import urlopen
import textwrap
import re

# %%
url = 'http://www.reuters.com/news/world'
text = urlopen(url).read().decode('utf8')

# %%
print(text)
# Out:
# <!--[if !IE]> This has been served from cache <![endif]-->
# <!--[if !IE]> Request served from apache server: produs--i-020683efceec17811 <![endif]-->
# <!--[if !IE]> Cached on Mon, 28 Jan 2019 05:21:08 GMT and will expire on Mon, 28 Jan 2019 05:26:07 GMT <![endif]-->
# <!--[if !IE]> token: 7e2516c7-8a59-4305-ab33-33101fdd3e76 <![endif]-->
# <!--[if !IE]> App Server /produs--i-017b109b90e7d00ce/ <![endif]-->
#
# <!doctype html><html lang="en" data-edition="BETAUS">
#     <head>
#
#     <title>World News | Reuters.com</title>
#             <meta name="google-site-verification" content="SVDMcE-27ZUUuh-EcZzejAJ0YIFjxD9H_nwAX6YVTw4" />
#             <meta name="google-site-verification" content="H9ahVdRxjlM56O9Un526uBCSaj_izzkfUjOCS--Zpco" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta http-equiv="x-dns-prefetch-control" content="on"><link rel="dns-prefetch" href="//s1.reutersmedia.net"/><link rel="dns-prefetch" href="//s2.reutersmedia.net"/><link rel="dns-prefetch" href="//s3.reutersmedia.net"/><link rel="dns-prefetch" href="//s4.reutersmedia.net"/><link rel="dns-prefetch" href="//static.reuters.com"/><link rel="dns-prefetch" href="//www.googletagservices.com"/><link rel="dns-prefetch" href="//www.googletagmanager.com"/><link rel="dns-prefetch" href="//www.google-analytics.com"/><link rel="dns-prefetch" href="//static.chartbeat.com"/><meta name="robots" content="index, follow">
#     <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no">
#
#     <!-- Segment -->
#     <script>
#     !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on"];analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);analytics.push(e);return analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t){var e=document.createElement("script");e.type="text/javascript";e.async=!0;e.src=("https:"===document.location.protocol?"https://":"http://")+"cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(e,n)};analytics.SNIPPET_VERSION="4.0.0";
#     }}();
#
#             analytics.ready(function () {
#                 if (typeof(ga) != "undefined") {
#                     ga('require', 'linker');
#                     ga('linker:autoLink', ['mobile.reuters.com']);
#                 }
#                 window.segment_user_id = analytics.user().anonymousId();
#             });
#         </script>
#
#     <!-- Page hiding snippet  -->
#     <style>.async-hide { opacity: 0 !important}</style>
#     <script>
#     (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;
#     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#     (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);
#     })(window,document.documentElement,'async-hide','dataLayer',2000,{'GTM-W9SLGS':true});
#     </script>
#
#     <!-- Data Layer Object Declaration -->
#     <script>window.dataLayer = window.dataLayer || [];</script>
#
#     <!-- New Google Tag Manager -->
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#         {'gtm.start': new Date().getTime(),event:'gtm.js'}
#         );var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-W9SLGS');</script>
#     <!-- End Google Tag Manager -->
#
#     <link href="//static.reuters.com/resources_v2/react/release/analytics-phase-02-ff9166be/common.bundle.css" rel="stylesheet">
#                     <link href="//static.reuters.com/resources_v2/react/release/analytics-phase-02-ff9166be/feed.bundle.css" rel="stylesheet">
#                 <div class="linebreak"></div>
# <script type="text/javascript">
#     window.Reuters = window.Reuters || {};
#     Reuters.info = Reuters.info || {};
#     Reuters.info.edition = Reuters.info.edition || 'BETAUS';
#     </script>
#
#     <script type="text/javascript">
#     var parallelMediaHosts = new Array();
#     parallelMediaHosts.push("s1.reutersmedia.net");parallelMediaHosts.push("s2.reutersmedia.net");parallelMediaHosts.push("s3.reutersmedia.net");parallelMediaHosts.push("s4.reutersmedia.net");</script>
#
#     <link rel="canonical" href="https://www.reuters.com/news/world" />
# <meta name="analyticsAttributes.author" content="Reuters Editorial" />
# <meta name="analyticsAttributes.canonicalUrl" content="https://www.reuters.com/news/world" />
# <meta name="analyticsAttributes.contentTitle" content="World News | Reuters.com" />
# <meta name="analyticsAttributes.edition" content="U.S." />
#
# <meta name="author" content="Reuters Editorial" />
# <meta name="description" content="Find late breaking world news from every corner of the globe at Reuters.com, your online source for international news coverage." />
# <meta name="keywords" content="International news,world news,global news,worldwide,Rueters,Roiters" />
# <meta name="news_keywords" content="International news;world news;global news;worldwide;Rueters;Roiters" />
#
# <meta property="og:description" content="Find late breaking world news from every corner of the globe at Reuters.com, your online source for international news coverage." />
# <meta property="og:image" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:site_name" content="U.S." />
# <meta property="og:title" content="World News | Reuters.com" />
# <meta property="og:type" content="section" />
# <meta property="og:url" content="https://www.reuters.com/news/world" />
#
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:description" content="Find late breaking world news from every corner of the globe at Reuters.com, your online source for international news coverage." />
# <meta name="twitter:image" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png" />
# <meta name="twitter:title" content="World News | Reuters.com" />
# <meta name="twitter:site" content="@Reuters" />
# <meta name="twitter:creator" content="@Reuters" />
#     <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "WebPage",
#         "headline": "World News | Reuters.com",
#         "url": "https://www.reuters.com/news/world",
#         "thumbnailUrl": "",
#         "dateCreated": "",
#         "description": "Find late breaking world news from every corner of the globe at Reuters.com, your online source for international news coverage.",
#         "publisher": "Reuters",
#         "creator": [],
#         "keywords": ["International news","world news","global news","worldwide","Rueters","Roiters","World"]
#     }
# </script>
#
#
# <script>
# if (abp == false || abp == '0'){ adBlocked = '0'; } else { adBlocked = '1'; }
# analytics.page('World', {
#     canonical_url: 'https://www.reuters.com/news/world',
#     content_channel: 'World - World',
#     content_type: 'Landing Page',
#     content_type_channel: 'Landing - News',
#     edition: 'U.S.',
#     keywords: 'International news,world news,global news,worldwide,Rueters,Roiters',
#     topic_channel: 'World',
#     topic_sub_channel: 'World',
#     ad_blocked: adBlocked,
#     platform: 'Desktop',
#     page_view_type: 'Page Load',
#     landing_sponsored: 'false',
#     pageView: '1'
# });
# if (document.referrer.indexOf('/article/') > -1) {
#     analytics.track('article.recirculation', {
#         canonical_url: 'https://www.reuters.com/news/world',
#         content_channel: 'World - World',
#         content_type: 'Landing Page',
#         content_type_channel: 'Landing - News',
#         edition: 'U.S.',
#         keywords: 'International news,world news,global news,worldwide,Rueters,Roiters',
#         topic_channel: 'World',
#         topic_sub_channel: 'World',
#         ad_blocked: adBlocked,
#         platform: 'Desktop',
#         page_view_type: 'Page Load',
#         landing_sponsored: 'false',
#         pageView: '1'
#     });
# }
# window.article_platform = 'Desktop';
# window.article_edition = 'U.S.';
# </script>
# <meta name="DCSext.DartZone" content="us.reuters/world/home" />
#     <meta name="analyticsAttributes.channel" content="Landing - News" />
#     <meta name="analyticsAttributes.contentType" content="Landing Page" />
#     <meta name="analyticsAttributes.contentChannel" content="World - World" />
#     <meta name="analyticsAttributes.topicChannel" content="World" />
#     <meta name="analyticsAttributes.topicSubChannel" content="World" />
#
#     <link rel="shortcut icon" type="image/x-icon" href="https://s3.reutersmedia.net/resources_v2/images/favicon/favicon.ico" />
#     <link rel="icon" type="image/x-icon" href="https://s3.reutersmedia.net/resources_v2/images/favicon/favicon.ico">
#     <link rel="apple-touch-icon" sizes="180x180" href="https://s3.reutersmedia.net/resources_v2/images/apple-touch-icon.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="https://s1.reutersmedia.net/resources_v2/images/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="https://s3.reutersmedia.net/resources_v2/images/favicon-16x16.png">
#     <link rel="mask-icon" href="https://s2.reutersmedia.net/resources_v2/images/safari-pinned-tab.svg" color="#ff8000">
#     <meta name="msapplication-TileColor" content="#ff8000">
#     <meta name="msapplication-TileImage" content="https://s2.reutersmedia.net/resources_v2/images/mstile-144x144.png">
#     <meta name="msapplication-square70x70logo" content="https://s1.reutersmedia.net/resources_v2/images/mstile-70x70.png" />
#     <meta name="msapplication-square150x150logo" content="https://s1.reutersmedia.net/resources_v2/images/mstile-150x150.png" />
#     <meta name="msapplication-wide310x150logo" content="https://s1.reutersmedia.net/resources_v2/images/mstile-310x150.png" />
#     <meta name="msapplication-square310x310logo" content="https://s1.reutersmedia.net/resources_v2/images/mstile-310x310.png" />
#     <meta name="msapplication-config" content="none"/>
#     <meta name="theme-color" content="#ffffff">
#
#     <script type='text/javascript'>
#             var _sf_async_config = _sf_async_config || {};
#             _sf_async_config.uid = 52639;
#             _sf_async_config.domain = 'reuters.com';
#             _sf_async_config.topStorageDomain = 'reuters.com';
#             _sf_async_config.path = document.querySelector("link[rel='canonical']").getAttribute("href").replace('https://www.', '').replace('http://www.', '');
#             _sf_async_config.flickerControl = false;
#             var _sf_startpt = (new Date()).getTime();
#         </script><script async src='//static.chartbeat.com/js/chartbeat_mab.js'></script></head>
# <body>
#     <!-- New Google Tag Manager (noscript) -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-W9SLGS" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <script type="text/javascript" >
#
# // Rubicon Initialize
# (function() {
#     var account_id = 11384;
#  var rct = document.createElement('script');
#         rct.type = 'text/javascript';
#         rct.async = true;
#         rct.src = (document.location.protocol === 'https:' ? 'https:' : 'http:') + '//ads.rubiconproject.com/header/' + account_id + '.js';
# var node = document.getElementsByTagName('script')[0];
#  node.parentNode.appendChild(rct);
# })();
#
# </script><div class="linebreak"></div>
#
# <div class="linebreak"></div>
#
# <div class="linebreak"></div>
# 	<script src="https://queso-cdn.prod.reuters.tv/new/assets/embedder.bundle.js"></script>
#     <div class="renderable" data-template="header" data-key="header_0hzp8gcnoe"><header role="header" class="Header_nav-container_1sQcl" id="header" data-reactroot=""><div class="TopBar_top-bar_3EBie"><div class="TopBar_left_3c-lj"><div class="Dropdown_dropdown_2IIaZ"><button class="Dropdown_button_dekwm"><span class="Dropdown_title_3X7VK">Discover Thomson Reuters</span><div class="Dropdown_dots_Rs2je"></div></button><div class="Dropdown_menu_29YmJ"><a href="https://financial.thomsonreuters.com/">Financial</a><a href="https://www.thomsonreuters.com/en/products-services/government-solutions.html">Government Solutions</a><a href="https://www.thomsonreuters.com/en/products-services/legal.html">Legal</a><a href="https://agency.reuters.com/en.html">Reuters News Agency</a><a href="https://risk.thomsonreuters.com/en.html">Risk Management Solutions</a><a href="https://www.thomsonreuters.com/en/products-services/tax-accounting.html">Tax &amp; Accounting</a><a href="https://blogs.thomsonreuters.com/answerson/">Blog: Answers On</a><a href="https://innovation.thomsonreuters.com/en.html">Innovation @ Thomson Reuters</a></div></div></div><div class="TopBar_right_1S9Sw"><div class="TopBar_item_2SsbV"><a href="https://www.thomsonreuters.com/en/global-gateway.html" class="TopBar_label_vRx1j">Directory of sites</a></div><div class="TopBar_item_2SsbV"><a href="https://www.thomsonreuters.com/en/login.html" class="TopBar_label_vRx1j">Login</a></div><div class="TopBar_item_2SsbV"><a href="https://reuters.zendesk.com/hc/en-us/articles/216467423-Contact-Reuters" class="TopBar_label_vRx1j">Contact</a></div><div class="TopBar_item_2SsbV"><a href="https://reuters.zendesk.com/hc/en-us" class="TopBar_label_vRx1j">Support</a></div></div></div><div class="Header_nav-content_3x7Pm"><div class="Header_nav-upper_88i17"><div class="Header_logo-nav_17D4i"><div class="Logo_logo_3iBgb" aria-label="Reuters"><a href="/" class="Logo_image_3prIB"><svg height="31px" width="137px" version="1.1" viewBox="0 0 137 31"><defs></defs><g id="navigation" fill="none" stroke="none" stroke-width="1"><g id="nav---with-channels" transform="translate(-195.000000, -56.000000)"><g id="Reuters-Logo" transform="translate(195.000000, 56.000000)"><path id="Fill-1" d="M12.2887066,16.9813081 C12.5343543,16.9271211 12.6914966,16.6796672 12.6490501,16.4295039 C12.5948631,16.1721157 12.3446999,15.9969111 12.0945366,16.0619355 C11.8290203,16.1061882 11.6754905,16.3572546 11.7278713,16.5974836 C11.780252,16.8620967 12.027706,17.0418169 12.2887066,16.9813081 M21.8355515,14.989033 C22.0830054,14.9321367 22.2383415,14.6873921 22.1967981,14.4363257 C22.1408049,14.175325 21.8897385,14.0001204 21.6404783,14.0660479 C21.3776714,14.1075913 21.2250447,14.361367 21.273813,14.6061116 C21.3243875,14.8644029 21.5745508,15.04322 21.8355515,14.989033 M13.4338584,19.0927945 C13.7264682,18.8534687 13.7616897,18.4506787 13.5530698,18.1680032 C13.3155501,17.8943589 12.9091477,17.8446875 12.6264722,18.0587261 C12.3510217,18.2682491 12.3004472,18.6836827 12.5271294,18.9672613 C12.7402649,19.2490337 13.1538923,19.3194768 13.4338584,19.0927945 M21.2385915,12.9678582 C21.5312012,12.7285323 21.5646165,12.3239361 21.3550935,12.0421638 C21.1202832,11.7712288 20.7120745,11.7206543 20.4330115,11.935596 C20.1602703,12.1478284 20.103374,12.5623589 20.3327656,12.8441313 C20.5468042,13.1259036 20.9595285,13.1954436 21.2385915,12.9678582 M15.9978062,20.5720994 C16.182042,20.1277661 15.9391037,19.6030554 15.4938672,19.4441069 C15.0233435,19.2607742 14.5338543,19.4910689 14.3414905,19.9661082 C14.167189,20.4131509 14.4065149,20.9161868 14.8671043,21.0950039 C15.3295,21.2485337 15.8271172,21.026367 15.9978062,20.5720994 M19.5443449,11.1056319 C19.7204526,10.6667173 19.4847392,10.1392972 19.0358902,9.98125185 C18.5671728,9.80153166 18.0794898,10.0327295 17.8835136,10.5032532 C17.7074058,10.9521021 17.9512473,11.455138 18.406418,11.6321489 C18.8706199,11.7820662 19.3691402,11.5671245 19.5443449,11.1056319 M21.1284112,16.6290926 C21.04 ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Freut.rs%2F2WoRcGd&amp;t=As%20West%20turns%20on%20him%2C%20Venezuela&#x27;s%20Maduro%20flexes%20military%20muscle" target="" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><button class="SocialTool_button_more"><svg height="7px" width="11px" version="1.1" viewBox="0 0 11 7"><defs></defs><g id="Symbols" fill="none" stroke="none" stroke-width="1"><g id="desktop/cards/Large-bullet-article" stroke="#86888B" stroke-width="1.5" transform="translate(-760.000000, -877.000000)"><g id="article-with-bullets"><g id="desktop/action-bar" transform="translate(0.000000, 850.000000)"><g id="icon/arrow-expander" transform="translate(761.000000, 28.000000)"><polyline id="arrow_right" points="0 4.302144 4.45432377 0.397671489 9 4.39767149" transform="translate(4.500000, 2.397671) scale(1, -1) translate(-4.500000, -2.397671) "></polyline></g></g></g></g></g></svg></button></li></ul></div></div></div></div></div><div class="FeedItem_item story_with_image_featured"><div class="FeedItem_cf"><div class="FeedItem_content-container"><div class="FeedItem_right-wrap"><div class="ImageStoryTemplate_image-story-container"><p class="FeedItemMeta_meta-container has-feature-decor FeedItemMeta_density-full"><a class="FeedItemMeta_channel" href="https://www.reuters.com/news/archive/worldNews">World News</a><span class="FeedItemMeta_date-updated">14 minutes ago</span><span class="FeedItemMeta_feature-decor" title="Top Headline" style="color:#f37021"><svg height="15px" width="10px" version="1.1" viewBox="0 0 10 15"><defs></defs><g id="Channel-Pages----Mobile" fill="none" stroke="none" stroke-width="1"><g id="Technology-Channel" transform="translate(-1034.000000, -941.000000)"><g id="article-01-copy" transform="translate(275.000000, 905.000000)"><g id="Featuired-flag" transform="translate(759.000000, 36.000000)"><polygon id="Rectangle-2" fill="#F36F21" points="0 2 10 2 7.33333333 5.63125 10 9 0 9"></polygon><rect height="14" id="Rectangle-12" width="1" rx="0.5" stroke="#F36F21" x="0.5" y="0.5"></rect></g></g></g></g></svg></span></p><div><h2 class="FeedItemHeadline_headline FeedItemHeadline_full"><a href="https://www.reuters.com/article/us-vale-sa-disaster/despair-turns-to-anger-as-brazilians-reckon-with-latest-dam-disaster-idUSKCN1PM0AP">Despair turns to anger as Brazilians reckon with latest dam&nbsp;disaster</a></h2></div><span><a href="https://www.reuters.com/article/us-vale-sa-disaster/despair-turns-to-anger-as-brazilians-reckon-with-latest-dam-disaster-idUSKCN1PM0AP"><img src="https://static.reuters.com/resources/r/?m=02&amp;d=20190128&amp;t=2&amp;i=1350581150&amp;r=LYNXNPEF0R09X&amp;w=640" alt="An ox is seen on mud after a tailings dam owned by Brazilian miner Vale SA burst, in Brumadinho, Brazil January 27, 2019. REUTERS/Adriano Machado  "/></a></span><div><p class="FeedItemLede_lede">Grief over the hundreds of Brazilians feared lost in a mining disaster on Friday has quickly hardened into anger as victims' families and politicians say iron ore miner Vale SA &lt;VALE3.SA&gt; and regulators have learned nothing from the recent&nbsp;past.</p></div></div><div class="FeedItem_icons"><ul class="SocialTool_container"><li><a href="https://www.twitter.com/share?url=https%3A%2F%2Freut.rs%2F2Wpcx2g&amp;text=Despair%20turns%20to%20anger%20as%20Brazilians%20reckon%20with%20latest%20dam%20disaster" target="" class="SocialTool_social-button SocialTool_twitter"><svg height="512.002px" id="Capa_1" style="enable-backg ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Freut.rs%2F2Wpcx2g&amp;t=Despair%20turns%20to%20anger%20as%20Brazilians%20reckon%20with%20latest%20dam%20disaster" target="" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><button class="SocialTool_button_more"><svg height="7px" width="11px" version="1.1" viewBox="0 0 11 7"><defs></defs><g id="Symbols" fill="none" stroke="none" stroke-width="1"><g id="desktop/cards/Large-bullet-article" stroke="#86888B" stroke-width="1.5" transform="translate(-760.000000, -877.000000)"><g id="article-with-bullets"><g id="desktop/action-bar" transform="translate(0.000000, 850.000000)"><g id="icon/arrow-expander" transform="translate(761.000000, 28.000000)"><polyline id="arrow_right" points="0 4.302144 4.45432377 0.397671489 9 4.39767149" transform="translate(4.500000, 2.397671) scale(1, -1) translate(-4.500000, -2.397671) "></polyline></g></g></g></g></g></svg></button></li></ul></div></div></div></div></div><div class="FeedItem_item story_with_image_featured"><div class="FeedItem_cf"><div class="FeedItem_content-container"><div class="FeedItem_right-wrap"><div class="ImageStoryTemplate_image-story-container"><p class="FeedItemMeta_meta-container has-feature-decor FeedItemMeta_density-full"><a class="FeedItemMeta_channel" href="https://www.reuters.com/news/archive/worldNews">World News</a><span class="FeedItemMeta_date-updated">18 minutes ago</span><span class="FeedItemMeta_feature-decor" title="Top Headline" style="color:#f37021"><svg height="15px" width="10px" version="1.1" viewBox="0 0 10 15"><defs></defs><g id="Channel-Pages----Mobile" fill="none" stroke="none" stroke-width="1"><g id="Technology-Channel" transform="translate(-1034.000000, -941.000000)"><g id="article-01-copy" transform="translate(275.000000, 905.000000)"><g id="Featuired-flag" transform="translate(759.000000, 36.000000)"><polygon id="Rectangle-2" fill="#F36F21" points="0 2 10 2 7.33333333 5.63125 10 9 0 9"></polygon><rect height="14" id="Rectangle-12" width="1" rx="0.5" stroke="#F36F21" x="0.5" y="0.5"></rect></g></g></g></g></svg></span></p><div><h2 class="FeedItemHeadline_headline FeedItemHeadline_full"><a href="https://www.reuters.com/article/us-myanmar-investment/suu-kyi-to-investors-myanmar-is-open-for-business-idUSKCN1PM0AM">Suu Kyi to investors: Myanmar is open for&nbsp;business</a></h2></div><span><a href="https://www.reuters.com/article/us-myanmar-investment/suu-kyi-to-investors-myanmar-is-open-for-business-idUSKCN1PM0AM"><img src="https://static.reuters.com/resources/r/?m=02&amp;d=20190128&amp;t=2&amp;i=1350579686&amp;r=LYNXNPEF0R097&amp;w=640" alt="FILE PHOTO: Myanmar’s leader Aung San Suu Kyi attends the ASEAN-China Summit in Singapore November 14, 2018. REUTERS/Edgar Su"/></a></span><div><p class="FeedItemLede_lede">Myanmar leader Aung San Suu Kyi on Monday urged global investors to put their money into Myanmar, seeking to offset the negative impact of the Rohingya crisis and slow pace of economic&nbsp;reforms.</p></div></div><div class="FeedItem_icons"><ul class="SocialTool_container"><li><a href="https://www.twitter.com/share?url=https%3A%2F%2Freut.rs%2F2RlUypM&amp;text=Suu%20Kyi%20to%20investors%3A%20Myanmar%20is%20open%20for%20business" target="" class="SocialTool_social-button SocialTool_twitter"><svg height="512.002px" id="Capa_1" style="enable-background:new 0 0 512.002 512.002" width="512.002px" version="1.1" viewBox="0 0 512.002 512.002" x="0px" y="0px" xml:space="preserve"><g><path d="M512.002,9 ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Freut.rs%2F2RlUypM&amp;t=Suu%20Kyi%20to%20investors%3A%20Myanmar%20is%20open%20for%20business" target="" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><button class="SocialTool_button_more"><svg height="7px" width="11px" version="1.1" viewBox="0 0 11 7"><defs></defs><g id="Symbols" fill="none" stroke="none" stroke-width="1"><g id="desktop/cards/Large-bullet-article" stroke="#86888B" stroke-width="1.5" transform="translate(-760.000000, -877.000000)"><g id="article-with-bullets"><g id="desktop/action-bar" transform="translate(0.000000, 850.000000)"><g id="icon/arrow-expander" transform="translate(761.000000, 28.000000)"><polyline id="arrow_right" points="0 4.302144 4.45432377 0.397671489 9 4.39767149" transform="translate(4.500000, 2.397671) scale(1, -1) translate(-4.500000, -2.397671) "></polyline></g></g></g></g></g></svg></button></li></ul></div></div></div></div></div><div class="FeedItem_item story_with_image_featured"><div class="FeedItem_cf"><div class="FeedItem_content-container"><div class="FeedItem_right-wrap"><div class="ImageStoryTemplate_image-story-container"><p class="FeedItemMeta_meta-container has-feature-decor FeedItemMeta_density-full"><a class="FeedItemMeta_channel" href="https://www.reuters.com/news/archive/worldNews">World News</a><span class="FeedItemMeta_date-updated">5 hours ago</span><span class="FeedItemMeta_feature-decor" title="Top Headline" style="color:#f37021"><svg height="15px" width="10px" version="1.1" viewBox="0 0 10 15"><defs></defs><g id="Channel-Pages----Mobile" fill="none" stroke="none" stroke-width="1"><g id="Technology-Channel" transform="translate(-1034.000000, -941.000000)"><g id="article-01-copy" transform="translate(275.000000, 905.000000)"><g id="Featuired-flag" transform="translate(759.000000, 36.000000)"><polygon id="Rectangle-2" fill="#F36F21" points="0 2 10 2 7.33333333 5.63125 10 9 0 9"></polygon><rect height="14" id="Rectangle-12" width="1" rx="0.5" stroke="#F36F21" x="0.5" y="0.5"></rect></g></g></g></g></svg></span></p><div><h2 class="FeedItemHeadline_headline FeedItemHeadline_full"><a href="https://www.reuters.com/article/us-britain-eu-business/get-a-grip-on-brexit-businesses-tell-uks-quarrelling-politicians-idUSKCN1PM007">'Get a grip on Brexit', businesses tell UK's quarrelling&nbsp;politicians</a></h2></div><span><a href="https://www.reuters.com/article/us-britain-eu-business/get-a-grip-on-brexit-businesses-tell-uks-quarrelling-politicians-idUSKCN1PM007"><img src="https://static.reuters.com/resources/r/?m=02&amp;d=20190128&amp;t=2&amp;i=1350512981&amp;r=LYNXNPEF0R003&amp;w=640" alt="FILE PHOTO: Demonstrators hold EU and Union flags during an anti-Brexit protest opposite the Houses of Parliament in London, Britain, December 17, 2018. REUTERS/Toby Melville"/></a></span><div><p class="FeedItemLede_lede">British businesses implored politicians on Monday to stop quarrelling over Brexit and agree an orderly exit from the European Union, as some big firms set up emergency situations rooms to cope with the possible tumult of a no-deal&nbsp;divorce.</p></div></div><div class="FeedItem_icons"><ul class="SocialTool_container"><li><a href="https://www.twitter.com/share?url=https%3A%2F%2Freut.rs%2F2WoLXX3&amp;text=&#x27;Get%20a%20grip%20on%20Brexit&#x27;%2C%20businesses%20tell%20UK&#x27;s%20quarrelling%20politicians" target="" class="SocialTool_social-button SocialTool_twitter"><svg height="512.002px" id="Capa_1" style="enable- ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Freut.rs%2F2WoLXX3&amp;t=&#x27;Get%20a%20grip%20on%20Brexit&#x27;%2C%20businesses%20tell%20UK&#x27;s%20quarrelling%20politicians" target="" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><button class="SocialTool_button_more"><svg height="7px" width="11px" version="1.1" viewBox="0 0 11 7"><defs></defs><g id="Symbols" fill="none" stroke="none" stroke-width="1"><g id="desktop/cards/Large-bullet-article" stroke="#86888B" stroke-width="1.5" transform="translate(-760.000000, -877.000000)"><g id="article-with-bullets"><g id="desktop/action-bar" transform="translate(0.000000, 850.000000)"><g id="icon/arrow-expander" transform="translate(761.000000, 28.000000)"><polyline id="arrow_right" points="0 4.302144 4.45432377 0.397671489 9 4.39767149" transform="translate(4.500000, 2.397671) scale(1, -1) translate(-4.500000, -2.397671) "></polyline></g></g></g></g></g></svg></button></li></ul></div></div></div></div></div><div class="FeedItem_item story_with_image_featured"><div class="FeedItem_cf"><div class="FeedItem_content-container"><div class="FeedItem_right-wrap"><div class="ImageStoryTemplate_image-story-container"><p class="FeedItemMeta_meta-container has-feature-decor FeedItemMeta_density-full"><a class="FeedItemMeta_channel" href="https://www.reuters.com/news/archive/worldNews">World News</a><span class="FeedItemMeta_date-updated">3 hours ago</span><span class="FeedItemMeta_feature-decor" title="Top Headline" style="color:#f37021"><svg height="15px" width="10px" version="1.1" viewBox="0 0 10 15"><defs></defs><g id="Channel-Pages----Mobile" fill="none" stroke="none" stroke-width="1"><g id="Technology-Channel" transform="translate(-1034.000000, -941.000000)"><g id="article-01-copy" transform="translate(275.000000, 905.000000)"><g id="Featuired-flag" transform="translate(759.000000, 36.000000)"><polygon id="Rectangle-2" fill="#F36F21" points="0 2 10 2 7.33333333 5.63125 10 9 0 9"></polygon><rect height="14" id="Rectangle-12" width="1" rx="0.5" stroke="#F36F21" x="0.5" y="0.5"></rect></g></g></g></g></svg></span></p><div><h2 class="FeedItemHeadline_headline FeedItemHeadline_full"><a href="https://www.reuters.com/article/us-philippines-security/philippines-vows-to-crush-terrorists-after-church-bombs-kill-20-idUSKCN1PL02W">Philippines vows to crush 'terrorists' after church bombs kill&nbsp;20</a></h2></div><span><a href="https://www.reuters.com/article/us-philippines-security/philippines-vows-to-crush-terrorists-after-church-bombs-kill-20-idUSKCN1PL02W"><img src="https://static.reuters.com/resources/r/?m=02&amp;d=20190127&amp;t=2&amp;i=1350337914&amp;r=LYNXNPEF0Q09Z&amp;w=640" alt="Debris lies scattered after a church bombing attack in Jolo, Sulu province, Philippines January 27, 2019. Armed Forces of the Philippines - Western Mindanao Command/Handout via REUTERS "/></a></span><div><p class="FeedItemLede_lede">The Philippines vowed to destroy those behind twin bombings that killed 20 people during a Sunday church service in the country's restive south, six days after a referendum on autonomy for the mainly Muslim region returned an overwhelming "yes"&nbsp;vote.</p></div></div><div class="FeedItem_icons"><ul class="SocialTool_container"><li><a href="https://www.twitter.com/share?url=https%3A%2F%2Freut.rs%2F2RiA8y1&amp;text=Philippines%20vows%20to%20crush%20&#x27;terrorists&#x27;%20after%20church%20bombs%20kill%2020" target="" class="SocialTool_social-button SocialTool_twitter"><svg h ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Freut.rs%2F2RiA8y1&amp;t=Philippines%20vows%20to%20crush%20&#x27;terrorists&#x27;%20after%20church%20bombs%20kill%2020" target="" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><button class="SocialTool_button_more"><svg height="7px" width="11px" version="1.1" viewBox="0 0 11 7"><defs></defs><g id="Symbols" fill="none" stroke="none" stroke-width="1"><g id="desktop/cards/Large-bullet-article" stroke="#86888B" stroke-width="1.5" transform="translate(-760.000000, -877.000000)"><g id="article-with-bullets"><g id="desktop/action-bar" transform="translate(0.000000, 850.000000)"><g id="icon/arrow-expander" transform="translate(761.000000, 28.000000)"><polyline id="arrow_right" points="0 4.302144 4.45432377 0.397671489 9 4.39767149" transform="translate(4.500000, 2.397671) scale(1, -1) translate(-4.500000, -2.397671) "></polyline></g></g></g></g></g></svg></button></li></ul></div></div></div></div></div><div class="FeedItem_item story_with_image_featured"><div class="FeedItem_cf"><div class="FeedItem_content-container"><div class="FeedItem_right-wrap"><div class="ImageStoryTemplate_image-story-container"><p class="FeedItemMeta_meta-container has-feature-decor FeedItemMeta_density-full"><a class="FeedItemMeta_channel" href="https://www.reuters.com/news/archive/worldNews">World News</a><span class="FeedItemMeta_date-updated">3 hours ago</span><span class="FeedItemMeta_feature-decor" title="Top Headline" style="color:#f37021"><svg height="15px" width="10px" version="1.1" viewBox="0 0 10 15"><defs></defs><g id="Channel-Pages----Mobile" fill="none" stroke="none" stroke-width="1"><g id="Technology-Channel" transform="translate(-1034.000000, -941.000000)"><g id="article-01-copy" transform="translate(275.000000, 905.000000)"><g id="Featuired-flag" transform="translate(759.000000, 36.000000)"><polygon id="Rectangle-2" fill="#F36F21" points="0 2 10 2 7.33333333 5.63125 10 9 0 9"></polygon><rect height="14" id="Rectangle-12" width="1" rx="0.5" stroke="#F36F21" x="0.5" y="0.5"></rect></g></g></g></g></svg></span></p><div><h2 class="FeedItemHeadline_headline FeedItemHeadline_full"><a href="https://www.reuters.com/article/us-china-australia-writer-pyne/australia-says-no-proof-writers-detention-in-china-related-to-canadian-arrests-idUSKCN1PM02I">Australia says no proof writer's detention in China related to Canadian&nbsp;arrests</a></h2></div><span><a href="https://www.reuters.com/article/us-china-australia-writer-pyne/australia-says-no-proof-writers-detention-in-china-related-to-canadian-arrests-idUSKCN1PM02I"><img src="https://static.reuters.com/resources/r/?m=02&amp;d=20190128&amp;t=2&amp;i=1350544096&amp;r=LYNXNPEF0R02F&amp;w=640" alt="Yang Hengjun, author and former Chinese diplomat, who is now an Australian citizen, display a name tag in an unspecified location in Tibet, China, mid-July, 2014 in this social media image obtained by REUTERS"/></a></span><div><p class="FeedItemLede_lede">There is no proof that Beijing's detention of a Chinese-born Australian writer is related to the arrest of Canadians in China, Australian Defence Minister Christopher Pyne said on&nbsp;Monday.</p></div></div><div class="FeedItem_icons"><ul class="SocialTool_container"><li><a href="https://www.twitter.com/share?url=https%3A%2F%2Freut.rs%2F2sNG4oT&amp;text=Australia%20says%20no%20proof%20writer&#x27;s%20detention%20in%20China%20related%20to%20Canadian%20arrests" target="" class="SocialTool_social-button Socia ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Freut.rs%2F2sNG4oT&amp;t=Australia%20says%20no%20proof%20writer&#x27;s%20detention%20in%20China%20related%20to%20Canadian%20arrests" target="" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><button class="SocialTool_button_more"><svg height="7px" width="11px" version="1.1" viewBox="0 0 11 7"><defs></defs><g id="Symbols" fill="none" stroke="none" stroke-width="1"><g id="desktop/cards/Large-bullet-article" stroke="#86888B" stroke-width="1.5" transform="translate(-760.000000, -877.000000)"><g id="article-with-bullets"><g id="desktop/action-bar" transform="translate(0.000000, 850.000000)"><g id="icon/arrow-expander" transform="translate(761.000000, 28.000000)"><polyline id="arrow_right" points="0 4.302144 4.45432377 0.397671489 9 4.39767149" transform="translate(4.500000, 2.397671) scale(1, -1) translate(-4.500000, -2.397671) "></polyline></g></g></g></g></g></svg></button></li></ul></div></div></div></div></div><div class="FeedItem_item story_with_image_featured"><div class="FeedItem_cf"><div class="FeedItem_content-container"><div class="FeedItem_right-wrap"><div class="ImageStoryTemplate_image-story-container"><p class="FeedItemMeta_meta-container has-feature-decor FeedItemMeta_density-full"><a class="FeedItemMeta_channel" href="https://www.reuters.com/news/archive/worldNews">World News</a><span class="FeedItemMeta_date-updated">26 minutes ago</span><span class="FeedItemMeta_feature-decor" title="Top Headline" style="color:#f37021"><svg height="15px" width="10px" version="1.1" viewBox="0 0 10 15"><defs></defs><g id="Channel-Pages----Mobile" fill="none" stroke="none" stroke-width="1"><g id="Technology-Channel" transform="translate(-1034.000000, -941.000000)"><g id="article-01-copy" transform="translate(275.000000, 905.000000)"><g id="Featuired-flag" transform="translate(759.000000, 36.000000)"><polygon id="Rectangle-2" fill="#F36F21" points="0 2 10 2 7.33333333 5.63125 10 9 0 9"></polygon><rect height="14" id="Rectangle-12" width="1" rx="0.5" stroke="#F36F21" x="0.5" y="0.5"></rect></g></g></g></g></svg></span></p><div><h2 class="FeedItemHeadline_headline FeedItemHeadline_full"><a href="https://www.reuters.com/article/us-china-rights/china-jails-prominent-rights-lawyer-for-4-1-2-years-for-subversion-idUSKCN1PM04C">China jails prominent rights lawyer for 4-1/2 years for&nbsp;subversion</a></h2></div><span><a href="https://www.reuters.com/article/us-china-rights/china-jails-prominent-rights-lawyer-for-4-1-2-years-for-subversion-idUSKCN1PM04C"><img src="https://static.reuters.com/resources/r/?m=02&amp;d=20190128&amp;t=2&amp;i=1350577480&amp;r=LYNXNPEF0R073&amp;w=640" alt="FILE PHOTO: Li Wenzu, the wife of prominent Chinese rights lawyer Wang Quanzhang, holds a box with a family picture and the detention notice for her husband before shaving her head in protest in Beijing, China, December 17, 2018.  REUTERS/Thomas Peter/File Photo"/></a></span><div><p class="FeedItemLede_lede">A Chinese court on Monday jailed prominent rights lawyer Wang Quanzhang for 4-1/2 years for subversion of state power. Human Rights Watch said the sentencing made a "mockery" of the Chinese leadership's claims to champion the rule of&nbsp;law.</p></div></div><div class="FeedItem_icons"><ul class="SocialTool_container"><li><a href="https://www.twitter.com/share?url=https%3A%2F%2Freut.rs%2F2Wih2ff&amp;text=China%20jails%20prominent%20rights%20lawyer%20for%204-1%2F2%20years%20for%20subversion" target="" cla ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
# ...
#  c-20.299,12.039-42.777,20.78-66.705,25.49c-19.16-20.415-46.461-33.17-76.674-33.17c-58.011,0-105.042,47.029-105.042,105.039
#  c0,8.233,0.929,16.25,2.72,23.939c-87.3-4.382-164.701-46.2-216.509-109.753c-9.042,15.514-14.223,33.558-14.223,52.809
#  c0,36.444,18.544,68.596,46.73,87.433c-17.219-0.546-33.416-5.271-47.577-13.139c-0.01,0.438-0.01,0.878-0.01,1.321
#  c0,50.894,36.209,93.348,84.261,103c-8.813,2.399-18.094,3.687-27.674,3.687c-6.769,0-13.349-0.66-19.764-1.888
#  c13.368,41.73,52.16,72.104,98.126,72.949c-35.95,28.176-81.243,44.967-130.458,44.967c-8.479,0-16.84-0.496-25.058-1.471
#  c46.486,29.807,101.701,47.197,161.021,47.197c193.211,0,298.868-160.062,298.868-298.872c0-4.554-0.104-9.084-0.305-13.59
#  C480.111,136.775,497.92,118.275,512.002,97.211z"></path></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g><g></g></svg></a></li><li><a href="https://www.facebook.com/Reuters" aria-label="Click Social facebook" target="_blank" class="SocialTool_social-button SocialTool_facebook"><svg id="Layer_1" style="enable-background:new 0 0 9 16" version="1.1" viewBox="0 0 9 16" x="0px" y="0px" xml:space="preserve"><path id="logo_facebook" d="M5.8,16V8.7h2.7l0.4-2.8H5.8V4c0-0.8,0.2-1.4,1.5-1.4H9V0.1C8.7,0.1,7.8,0,6.6,0c-2.3,0-4,1.3-4,3.8v2.1 H0v2.8h2.7V16H5.8L5.8,16z"></path></svg></a></li><li><a href="https://www.youtube.com/user/ReutersVideo" aria-label="Click Social youtube" target="_blank" class="SocialTool_social-button SocialTool_youtube"><svg id="Capa_1" viewBox="0 0 17.01 11.94" data-name="Capa 1"><path d="M12,6,6.11,9.27V2.69ZM17.5,9V2.92A2.94,2.94,0,0,0,14.4,0H2.6S-.5,0-.5,2.92V9A2.93,2.93,0,0,0,2.6,12H14.4S17.5,12,17.5,9"></path></svg></a></li><li><a href="https://instagram.com/reuters/" aria-label="Click Social instagram" target="_blank" class="SocialTool_social-button SocialTool_instagram"><svg id="Layer_1" style="enable-background:new 0 0 14 14" version="1.1" viewBox="0 0 14 14" x="0px" y="0px" xml:space="preserve"><g><path d="M7,4.7c-1.3,0-2.3,1-2.3,2.3s1,2.3,2.3,2.3c0,0,0,0,0,0c1.3,0,2.3-1,2.3-2.3c0,0,0,0,0,0C9.3,5.7,8.3,4.7,7,4.7z"></path><path d="M14,4.1c0-0.6-0.1-1.2-0.3-1.7c-0.4-0.9-1.1-1.7-2-2C11,0.2,10.5,0.1,9.9,0C9.1,0,8.9,0,7,0S4.9,0,4.1,0 C3.5,0.1,3,0.2,2.4,0.4c-0.9,0.4-1.7,1.1-2,2C0.2,3,0.1,3.5,0,4.1c0,0.8,0,1,0,2.9s0,2.1,0,2.9c0,0.6,0.1,1.2,0.3,1.7 c0.4,0.9,1.1,1.7,2,2C3,13.8,3.5,13.9,4.1,14c0.8,0,1,0,2.9,0s2.1,0,2.9,0c0.6,0,1.2-0.1,1.7-0.3c0.9-0.4,1.7-1.1,2-2 c0.2-0.5,0.3-1.1,0.3-1.7c0-0.8,0-1,0-2.9S14,4.9,14,4.1z M10.6,7c0,2-1.6,3.6-3.6,3.6C5,10.6,3.4,9,3.4,7C3.4,5,5,3.4,7,3.4 c0,0,0,0,0,0C9,3.4,10.6,5,10.6,7C10.6,7,10.6,7,10.6,7z M11.6,3.3c0,0.5-0.4,0.8-0.8,0.8c-0.5,0-0.8-0.4-0.8-0.8 c0-0.5,0.4-0.8,0.8-0.8c0,0,0,0,0,0C11.2,2.4,11.6,2.8,11.6,3.3C11.6,3.3,11.6,3.3,11.6,3.3z"></path></g></svg></a></li><li><a href="https://www.linkedin.com/company/10256858/" aria-label="Click Social linkedin" target="_blank" class="SocialTool_social-button SocialTool_linkedin"><svg id="Layer_1" style="enable-background:new 0 0 12 12" version="1.1" viewBox="0 0 12 12" x="0px" y="0px" xml:space="preserve"><path id="logo_linkedin" d="M0.1,12V3.6h2.6V12H0.1 M2.7,1.3c0,0.7-0.6,1.4-1.3,1.4C0.6,2.7,0,2.1,0,1.4S0.5,0,1.3,0c0,0,0,0,0.1,0 C2.1,0,2.7,0.5,2.7,1.3C2.7,1.2,2.7,1.3,2.7,1.3 M9.4,12V7.4c0-1.1-0.4-1.8-1.3-1.8c-0.6,0-1.1,0.4-1.3,1C6.7,6.7,6.7,7,6.7,7.2V12 H4.2V6.3c0-1,0-1.9-0.1-2.7h2.2l0.1,1.2h0C7,3.9,8,3.4,9,3.4c1.7,0,3,1.1,3,3.6V12H9.4"></path></svg></a></li><li><a href="//www.reuters.com/tools/rss" aria-label="Click Social rss" target="_blank" class="SocialTool_social-button SocialTool_rss"><svg id="Capa_1" viewBox="0 0 17.01 17.01" data-name="Capa 1"><path id="RSS" d="M3.85,13.15a2.24,2.24,0,0,1,0,3.18h0a2.26,2.26,0,0,1-3.19,0,2.24,2.24,0,0,1,0-3.18h0a2.25,2.25,0,0,1,3.19,0Zm0,0h0ZM.66,16.33h0ZM0,5.78V9a7.92,7.92,0,0,1,5.62,2.34A7.94,7.94,0,0,1,8,17h3.26A11.2,11.2,0,0,0,7.93,9.08,11.18,11.18,0,0,0,0,5.78ZM0,0V3.25A13.78,13.78,0,0,1,13.75,17H17A17,17,0,0,0,12,5,17,17,0,0,0,0,0Z"></path></svg></a></li></ul></div></div></div><div class="Footer_legal"><div class="Footer_inner"><p><span>All quotes delayed a minimum of 15 minutes. See </span><a href="//www.reuters.com/info/disclaimer" target="_blank">here for a complete list</a><span> of exchanges and delays.</span></p><p><a href="//thomsonreuters.com/copyright/ " target="_blank"><span>© <!-- -->2019<!-- --> </span><span>Reuters. All Rights Reserved.</span></a></p></div></div></div></div></div></div><div style="height:0"><span></span></div></footer></div><script type="text/javascript">window.RCOM_Data = {"header_0hzp8gcnoe":{"template":"header","evergreens":[{"url":"https://www.reuters.com/news/world","name":"World","sponsored":fals ...
#     var _sf_startpt = (new Date()).getTime();
#     var _sf_async_config = _sf_async_config || {};
#
#     _sf_async_config.playerdomain = 'queso-cdn.prod.reuters.tv';
#     _sf_async_config.sections = 'World';
#     _sf_async_config.autoDetect = false;
#
#     _sf_async_config.authors = 'Reuters Editorial';
#     _sf_async_config.type = 'Landing Page';
#
#     (function(){
#       function loadChartbeat() {
#         window._sf_endpt=(new Date()).getTime();
#         var e = document.createElement('script');
#         e.setAttribute('language', 'javascript');
#         e.setAttribute('type', 'text/javascript');
#         e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');
#         document.body.appendChild(e);
#       }
#       var oldonload = window.onload;
#       window.onload = (typeof window.onload != 'function') ?
#          loadChartbeat : function() { oldonload(); loadChartbeat(); };
#     })();
#   </script>
# <script src="//static.reuters.com/resources_v2/react/release/analytics-phase-02-ff9166be/common.bundle.js" ></script>
#                 <script src="//static.reuters.com/resources_v2/react/release/analytics-phase-02-ff9166be/feed.bundle.js" ></script>
#             <script type="text/javascript">
# /* 20190128061902 */ !function(e,t,r){function n(e,t){var r=X(e);if(!r)return r;if(""!=t)for(var n=0;n<t.length;n++)"^"==t.charAt(n)&&(r=r.parentNode),"<"==t.charAt(n)&&(r=r.previousElementSibling),">"==t.charAt(n)&&(r=r.nextElementSibling),"y"==t.charAt(n)&&(r=r.firstChild);return r}function l(e,t){var r=t.getBoundingClientRect(),n=e.clientX-r.left,l=e.clientY-r.top;return{x:n,y:l}}function o(e){for(var t=0,r=0;e;)t+=e.offsetLeft+e.clientLeft,r+=e.offsetTop+e.clientTop,e=e.offsetParent;return{x:t,y:r}}function d(e,t){var r=0,n=0,l=o(t);return(e.pageX||e.pageY)&&(r=e.pageX,n=e.pageY),(e.clientX||e.clientY)&&(r=e.clientX+document.body.scrollLeft+document.documentElement.scrollLeft,n=e.clientY+document.body.scrollTop+document.documentElement.scrollTop),r-=l.x,n-=l.y,{x:r,y:n}}function s(e,t){return t.getBoundingClientRect?l(e,t):d(e,t)}function c(e,t){e.addEventListener?e.addEventListener("click",t,!0):e.attachEvent&&e.attachEvent("onclick",function(){return t.call(e,window.event)})}function p(e){return parseInt(e.toString().split(".")[0])}function u(){return ge=(he*ge+ve)%ye}function f(){return u()/(ye-1)}function y(){return f()}function h(e,t){return e>t?e:t}function v(e){if("function"==typeof e.createShadowRoot)try{var t=e.createShadowRoot();t.innerHTML=atob("ICAgICAgICA8Y29udGVudD48L2NvbnRlbnQ+DQogICAgICAgIDxzdHlsZT4jamtkZnZqayB7IG1hcmdpbjogMDsgcGFkZGluZzogMDsgYmFja2dyb3VuZDogdHJhbnNwYXJlbnQ7IH1ib2R5IHttYXJnaW46IDBweCFpbXBvcnRhbnQ7fTwvc3R5bGU+DQogICAg")}catch(e){}}function g(e){m(e)}function m(e){if(e.rllyb44sdl&&!e.rllydbdInject){e.rllydbdInject=!0,e.rlly18aPc={},e.rlly73fOc=[],e.rlly31cAv={},e.rlly31cAvt={};var r=[];e.rllyc3enewinject=!1,e.rlly94aFlags.newInject=!1;var n="S''ponsoreᗞ",l="opacity: 0.75; font-size: 10px; position: relative; margin-top: 3px; display: block; text-align: left; font-family: knowledge-medium,sans-serif; -webkit-font-smoothing: antialiased; font-size: 12px; color: #86888b; text-transform: uppercase; letter-spacing: .2rem; ",i=/^[a-z]+/.exec(location.host);if(i)switch(i[0]){case"de":n="G''esponserТ"}var a=".k872ABr9",o=document.createElement("style");o.innerHTML=a+":before { content: '"+n+"'; "+l+" } span"+a+"{ display: block; }",document.head.appendChild(o);var d='div[class*="content"] > div[class*="left"] > div[class*="container"] > div[class*="body"]',s=[],c=(setInterval(function(){s=document.querySelectorAll(d)},1e3),40),u=0,f=setInterval(function(){if(r&&r.MRTop){clearInterval(f);var e=r.MRTop;if(location.pathname.indexOf("/picture/")>-1)e.style.setProperty("bottom","80px"),e.style.setProperty("position","absolute"),e.style.setProperty("left","800px");else{for(var t,n=document.querySelectorAll(".dark.group"),l=e.parentNode,i=l;l.scrollHeight-e.scrollHeight<100;)t=l.parentNode.className,i=t.indexOf("group")>-1&&t.indexOf("wrap")>-1?l:l.parentNode,l=l.parentNode;window.addEventListener&&window.addEventListener("scroll",function(t){if(i.getBoundingClientRect().bottom<-20){e.style.setProperty("position","fixed"),e.style.setProperty("top","50px");for(var r=0;r<n.length;r++){if(n[r].getBoundingClientRect().top<350&&n[r].getBoundingClientRect().bottom>0){e.style.setProperty("display","none","important");break}e.style.setProperty("display","inherit","important")}}else e.style.setProperty("position","static"),e.style.setProperty("top",null)})}}u++>=c&&clearInterval(f)},500),h=40,g=0,m=setInterval(function(){if(r&&r.ARTEND){clearInterval(m);var e,t,n=r.ARTEND,l=document.querySelector(d);window.addEventListener&&window.addEventListener("scroll",function(i){for(var a=0;a<s.length;a++)s[a].getBoundingClientRect().top<0&&s[a].getBoundingClientRect().bottom>0&&s[a]!=l&&(e=document.createElement("div"),e.style.setProperty("height","331px"),e.className="replacementSpace",t=l.querySelector(".StandardArticleBody_trustBadgeContainer"),t&&t.appendChild(e),l=s[a],t=l.querySelector(".StandardArticleBody_trustBadgeContainer"),t&&(e=t.getElementsByClassName("replacementSpace")[0],e&&t.removeChild(e)),t&&(r.ARTEND=t.ap ...
# var a=W("div");q(a,'<div class="k872ABr9 kvt67r8h"> </div>'),G(a.childNodes,function(e,t){H(l,t)}),se(l,5771,ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@77)g@534:4338)w@9)l@486339:358)u@JV]GE"+e.rllya53Rnd+")z@344",-3))}}},O)}function y(){Y(ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@78)g@534;3<59)w@4)l@9699464::9)u@GRZZM"+e.rllya53Rnd+")z@344",-3),function(){if(O(),!I){I=!0;var r=this;if(!(r.height<2)){var n=N,l=W("div");t.RightRailImage=l,V(l,"ehTuMdoug");var i=r;c(i,function(t,r){if(!e.rlly18aPc[5122]){t.preventDefault(),t.stopPropagation();for(var r=s(t,this),n=0;n<e.rlly73fOc.length;n++){var l=e.rlly73fOc[n];if(5122==l.p&&r.x>=l.x&&r.x<l.x+l.w&&r.y>=l.y&&r.y<l.y+l.h){if(l.u){var i=l.t.length>0?l.t:"_self";i=0==t.button&&t.ctrlKey?"_blank":i,ee(e,l.u,i,!0)}return}}var a=[ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@;7)g@53483759)w@<)l@875;377<75)u@\\WIXG"+e.rllya53Rnd+")z@344",-3),ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@;9)g@53483735)w@9)l@<35965:573)u@XHS\\U"+e.rllya53Rnd+")z@343",-3),ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@89)g@534;3437)w@4)l@8<<<3694<:)u@ZQF]["+e.rllya53Rnd+")z@343",-3),ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@6:)g@534:3447)w@5)l@6587859<45)u@EV]XO"+e.rllya53Rnd+")z@344",-3),ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@4;)g@534:3634)w@7)l@44;8643888)u@E[]F]"+e.rllya53Rnd+")z@343",-3)],o=a[1*p(5*r.y/this.offsetHeight)+p(1*r.x/this.offsetWidth)];ee(e,o,0==t.button&&t.ctrlKey?"_blank":"_self")}}),U(l,r),U(n,l),e.rllyd1b64.a[5122]=l;var a=W("div");q(a,'<span class="R0b783dj"> </span> <div class="xgRt9xyY"> </div> <div class="A8JD8jn3"> </div> <div class="R0b783dj"> </div> <div class="R0b783dj"> </div>'),G(a.childNodes,function(e,t){D(l,t)});var a=W("div");q(a,'<div class="k872ABr9 s912CDz8"> </div>'),G(a.childNodes,function(e,t){H(l,t)}),E([{function:function(){if(!window.rllyb1eMobile){var e=!1;window.scrollBy(0,10);setTimeout(function(){window.scrollBy(0,-10),setTimeout(function(){window.scrollBy(0,10),setTimeout(function(){window.scrollBy(0,-10)},0)},2e3)},0);window.addEventListener&&window.addEventListener("scroll",function(r){var n=t.RightRailImage;if(n){var l=n.parentNode;if(l){!e&&document.querySelector("iframe[src*='prod.reuters.tv/new/index.html?autoplay=true']")&&(n.style.setProperty("margin-top","187px"),e=!0);var i=document.querySelector(".k872ABr9.s912CDz8");l.getBoundingClientRect().top<35?(n.style.setProperty("position","fixed"),n.style.setProperty("top","35px"),i&&(i.style.setProperty("position","fixed"),i.style.setProperty("top","20px"))):(n.style.setProperty("position","absolute"),n.style.setProperty("top",null),i&&(i.style.setProperty("position","absolute"),i.style.setProperty("top","-15px")))}}})}}}],l),se(l,5122,ne("2uhvrxufhv2lpdjhv2k21jli2e2Bd@4)p@8;)g@534;4343)w@9)l@89337498;9)u@RG[SW"+e.rllya53Rnd+")z@344",-3))}}},O)}if(e.rllybe8Ptl=8,e.rlly19ePl=0,location.href.indexOf("/article/")>-1){var h=r.ARTENDWrapperChild,v=!1;h?l():O()}else O();if(e.rllyb1eMobile){var g=r.ARTENDREUTERSMOBILEWrapper,m=!1;g?i():O()}else O();var x=r.BILLWrapperChild,b=!1;if(x?a():O(),e.rllyb1eMobile){var w=r.MRMobileWrapper,j=!1;w?o():O()}else O();if(location.pathname.indexOf("/article/")!==-1||e.rllyb1eMobile||location.pathname.indexOf("/news/picture/")!==-1)O();else{var R=n("#div_gpt_mpu, #ad-div-mpu","^"),k=!1;R?d():O()}if(e.rllyb1eMobile){var T=n("body > section.module.top-news-module",""),S=!1;T?u():O()}else O();if(!e.rllyb1eMobile&&location.pathname.indexOf("/news/picture/")>-1){var P=r.MRTopPictureWrapper,A=!1;P?f():O()}else O();if(e.rllyb1eMobile)O();else{var N=r.RightRailImageWrapperChild,I=!1;N?y():O()}(e.rllyautorecov||e.rlly94aFlags.autoRecov)&&de(),B()}function B(){G(Z(".RightRail_sticky-container"),function(e,t){t.className.indexOf(" rllyHid")<0&&(t.className+=" rllyHid")})}function O(){e.rlly19ePl++,e.rlly19ePl>=e.rllybe8Ptl&&(S(),me=!1)}function S(){var t=function(t){if(null!==t.data&&"object"==typeof t.data)try{var r=t.data,n=document.createElement("a");if(n.href=t.origin,window.location.hostname!=n.hostname)return;if("cc"==r ...
# s(t))}(window,document,Math);var xe=X("head"),be=null;if(e.addEventListener?e.addEventListener("addefend.init",F,!1):e.attachEvent&&e.attachEvent("addefend.init",F),"complete"===t.readyState?F():(navigator.userAgent.search("Firefox")==-1&&(t.addEventListener?t.addEventListener("DOMContentLoaded",F,!1):t.attachEvent&&t.attachEvent("onreadystatechange",function(){"complete"===t.readyState&&F()})),e.addEventListener?e.addEventListener("load",F,!1):e.attachEvent&&e.attachEvent("onload",F)),e.rllyd1b6tc={},e.rllyd1b6tc.pm=!1,e.rllyd1b6tc.pmd=!1,/Firefox/.test(window.navigator.userAgent))if(e.rlly94aFlags.networkListener){var we=!1;Object.keys(e).forEach(function(t){e.hasOwnProperty(t)&&t.match(/^rlly.{3}NLRun$/g)&&(we=e[t])}),we?(e.rllynl=!0,e.rllyd1b6tc.pmd=!0,I()):(e.rlly2abNLRun=!0,ue(),fe())}else e.rllynl=!0,e.rllyd1b6tc.pmd=!0,I();else e.rllyd1b6tc.pmd=!0,I()}catch(e){}}(window,document,Math); /* ccbe654cee368ceedccc4419f9d523b3 */</script>
# </body>
# </html>
